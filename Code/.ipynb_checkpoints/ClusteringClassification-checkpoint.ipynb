# %%
import time
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import missingno as msno
import plotly.graph_objects as go
from datetime import datetime
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, classification_report, confusion_matrix
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import f_classif, mutual_info_classif, VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score
from scipy.spatial.distance import cdist , pdist
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import KMeans
from imblearn.over_sampling import SMOTE
np.random.seed(42)


#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Allow long lines

# %%
# Specify the path to the CSV file in the parent directory
file_path = "../Dataset/pd_speech_features/pd_speech_features.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path, sep=',',skiprows=1)

# %% [markdown]
# # SMOTE

# %%
X=df.drop('class',axis=1)
y=df['class']
smote_female = SMOTE(sampling_strategy='auto', random_state=42)
X_smote, y_smote = smote_female.fit_resample(X, y)

# %%
unique, counts = np.unique(y, return_counts=True)
original_class_distribution = dict(zip(unique, counts))
unique, counts = np.unique(y_smote, return_counts=True)
resampled_class_distribution = dict(zip(unique, counts))

print("Original class distribution:", original_class_distribution)
print("Resampled class distribution:", resampled_class_distribution)
# Out:
# Original class distribution: {0: 192, 1: 564}
# Resampled class distribution: {0: 564, 1: 564}

# %% [markdown]
# # Normalization

# %%
features = X_smote.columns

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Scale the features
X_smote_scaled = pd.DataFrame(scaler.fit_transform(X_smote[features]), columns=features)

# %% [markdown]
# # Correlation

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything else
# without any further insight.

def correlation(dataset, threshold):
    
    # create a set where I will store the names of correlated columns
    col_corr = set()
    
    # create the correlation matrix
    corr_matrix = dataset.corr()
    
    # for each feature in the dataset (columns of the correlation matrix)
    for i in range(len(corr_matrix.columns)):
        
        # check with other features
        for j in range(i):
            
            # if the correlation is higher than a certain threshold
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                
                # print correlation, and variables examined
                # keep in mind that the columns and rows of the dataframe are identical
                # so we can identify the features being examned by looking for i,j
                # in the column names
                print(abs(corr_matrix.iloc[i, j]), corr_matrix.columns[i], corr_matrix.columns[j])
                
                # get the name of the correlated feature
                colname = corr_matrix.columns[j]
                
                # and add it to our correlated set
                col_corr.add(colname)
                
    return col_corr

# %%
corr_features = correlation(X_smote_scaled, 0.8)
print(len(set(corr_features)))
# Out:
# 0.9999432689018055 numPeriodsPulses numPulses
# 0.8986132933725358 meanPeriodPulses numPulses
# 0.8983673930084992 meanPeriodPulses numPeriodsPulses
# 0.9661935294503162 locAbsJitter locPctJitter
# 0.9630044333235679 rapJitter locPctJitter
# 0.9523930582366162 rapJitter locAbsJitter
# 0.9588585734818649 ppq5Jitter locPctJitter
# 0.9463274034200975 ppq5Jitter locAbsJitter
# 0.9730870895529791 ppq5Jitter rapJitter
# 0.9630138707762759 ddpJitter locPctJitter
# 0.9524350064260689 ddpJitter locAbsJitter
# 0.9999952815668337 ddpJitter rapJitter
# 0.9730904927213517 ddpJitter ppq5Jitter
# 0.9963555383695369 locDbShimmer locShimmer
# 0.98227423726979 apq3Shimmer locShimmer
# 0.9753334571838319 apq3Shimmer locDbShimmer
# 0.9794835275244602 apq5Shimmer locShimmer
# 0.9739622437541159 apq5Shimmer locDbShimmer
# 0.9600580219538976 apq5Shimmer apq3Shimmer
# 0.8923216472144624 apq11Shimmer locShimmer
# 0.8952548895514163 apq11Shimmer locDbShimmer
# 0.8426943117841876 apq11Shimmer apq3Shimmer
# 0.9145399117118357 apq11Shimmer apq5Shimmer
# 0.9822745790489839 ddaShimmer locShimmer
# 0.9753333652318095 ddaShimmer locDbShimmer
# 0.9999999927013931 ddaShimmer apq3Shimmer
# 0.9600577998385329 ddaShimmer apq5Shimmer
# 0.8426957461110914 ddaShimmer apq11Shimmer
# 0.9882267367022628 meanNoiseToHarmHarmonicity meanAutoCorrHarmonicity
# 0.8038101347335871 meanHarmToNoiseHarmonicity locShimmer
# 0.8081401031506938 meanHarmToNoiseHarmonicity locDbShimmer
# 0.8113123550956405 meanHarmToNoiseHarmonicity meanAutoCorrHarmonicity
# 0.8721838355947339 maxIntensity minIntensity
# 0.9123647299347762 meanIntensity minIntensity
# 0.9879457374082027 meanIntensity maxIntensity
# 0.8112567892951318 GNE_std GNE_mean
# 0.9248589082026846 GNE_NSR_TKEO GNE_SNR_TKEO
# 0.9857087520581789 VFER_entropy VFER_mean
# 0.9771024119032867 IMF_NSR_entropy IMF_NSR_SEO
# 0.8468316583701396 mean_0th_delta mean_delta_log_energy
# 0.8647203409065506 std_MFCC_0th_coef std_Log_energy
# 0.8911728812567712 std_delta_log_energy std_Log_energy
# 0.8410263970996287 std_0th_delta std_MFCC_0th_coef
# 0.9082187450544724 std_1st_delta std_MFCC_1st_coef
# 0.8236079325643461 std_3rd_delta std_MFCC_3rd_coef
# 0.8566389393995516 std_4th_delta std_MFCC_4th_coef
# 0.8082038950468873 std_5th_delta std_4th_delta
# 0.8045854969303919 std_6th_delta std_5th_delta
# 0.8009159366419479 std_8th_delta std_MFCC_8th_coef
# 0.8094810288911517 std_10th_delta std_MFCC_10th_coef
# 0.927210581289076 std_delta_delta_log_energy std_delta_log_energy
# 0.8646157787446419 std_delta_delta_0th std_0th_delta
# 0.8287219893937429 std_delta_delta_0th std_1st_delta
# 0.8727234536981744 std_1st_delta_delta std_MFCC_1st_coef
# 0.9558875564184761 std_1st_delta_delta std_1st_delta
# 0.8182073275866696 std_1st_delta_delta std_delta_delta_0th
# 0.9479042167115275 std_2nd_delta_delta std_2nd_delta
# 0.9559402144397346 std_3rd_delta_delta std_3rd_delta
# 0.8178674015928885 std_4th_delta_delta std_MFCC_4th_coef
# 0.9558631611949941 std_4th_delta_delta std_4th_delta
# 0.8092739950407213 std_4th_delta_delta std_3rd_delta_delta
# 0.8108601235349869 std_5th_delta_delta std_4th_delta
# 0.9522209322551671 std_5th_delta_delta std_5th_delta
# 0.8387422897413362 std_5th_delta_delta std_4th_delta_delta
# 0.9440590929531976 std_6th_delta_delta std_6th_delta
# 0.8009580274570579 std_6th_delta_delta std_4th_delta_delta
# 0.8164391593067792 std_6th_delta_delta std_5th_delta_delta
# 0.9488234111116796 std_7th_delta_delta std_7th_delta
# 0.9419542434745366 std_8th_delta_delta std_8th_delta
# 0.9515274698837826 std_9th_delta_delta std_9th_delta
# 0.8181954470847276 std_9th_delta_delta std_8th_delta_delta
# 0.9503769171758586 std_10th_delta_delta std_10th_delta
# 0.8041158530677834 std_10th_delta_delta std_9th_delta_delta
# 0.9326296416075642 std_11th_delta_delta std_11th_delta
# 0.9467302676505275 std_12th_delta_delta std_12th_delta
# 0.9295186357066653 Ed_2_coef Ed_1_coef
# 0.9088589268622828 Ed_3_coef Ed_2_coef
# 0.8272303041739123 Ed_5_coef Ed_2_coef
# 0.8432601420535364 Ed_5_coef Ed_4_coef
# 0.8175727352337457 Ed_6_coef Ed_5_coef
# 0.8584463615854558 Ed_8_coef Ea
# 0.8203970495408159 Ed_9_coef Ed_7_coef
# 0.8817308421593458 Ed_10_coef Ea
# 0.8283285184708945 Ed_10_coef Ed_8_coef
# 0.9162442681776507 det_entropy_shannon_1_coef Ed_1_coef
# 0.8659799306930288 det_entropy_shannon_1_coef Ed_2_coef
# 0.8089355968726957 det_entropy_shannon_1_coef Ed_3_coef
# 0.8039910729520362 det_entropy_shannon_2_coef Ed_1_coef
# 0.9121823708829503 det_entropy_shannon_2_coef Ed_2_coef
# 0.9424740509435036 det_entropy_shannon_2_coef Ed_3_coef
# 0.9071307843692131 det_entropy_shannon_2_coef det_entropy_shannon_1_coef
# 0.8017381986076596 det_entropy_shannon_3_coef Ed_2_coef
# 0.9478306690051621 det_entropy_shannon_3_coef Ed_3_coef
# 0.9335080835749081 det_entropy_shannon_3_coef det_entropy_shannon_2_coef
# 0.8619047064660837 det_entropy_shannon_5_coef Ed_5_coef
# 0.8235261771825432 det_entropy_shannon_8_coef Ed_8_coef
# 0.8065867569702803 det_entropy_shannon_10_coef Ed_8_coef
# 0.8288667624051 det_entropy_shannon_10_coef Ed_10_coef
# 0.8472390180442573 det_entropy_shannon_10_coef det_entropy_shannon_8_coef
# 0.9314287815325414 det_entropy_log_2_coef det_entropy_log_1_coef
# 0.8615048300328403 det_entropy_log_3_coef det_entropy_log_2_coef
# 0.8508955059913976 det_entropy_log_4_coef det_entropy_log_3_coef
# 0.8088982891392371 det_entropy_log_5_coef det_entropy_log_3_coef
# 0.9010439931253735 det_entropy_log_5_coef det_entropy_log_4_coef
# 0.8288883948045773 det_entropy_log_6_coef det_entropy_log_4_coef
# 0.8574688799242137 det_entropy_log_6_coef det_entropy_log_5_coef
# 0.8656044825960538 det_entropy_log_7_coef det_entropy_log_6_coef
# 0.8167197463992916 det_entropy_log_8_coef det_entropy_log_6_coef
# 0.9214287699721342 det_entropy_log_8_coef det_entropy_log_7_coef
# 0.8470738542568249 det_entropy_log_9_coef det_entropy_log_7_coef
# 0.9168129623224739 det_entropy_log_9_coef det_entropy_log_8_coef
# 0.8485999403007202 det_entropy_log_10_coef det_entropy_log_8_coef
# 0.9567580571393964 det_entropy_log_10_coef det_entropy_log_9_coef
# 0.9061385085102162 det_TKEO_mean_1_coef Ed_1_coef
# 0.8923702018591815 det_TKEO_mean_1_coef Ed_2_coef
# 0.8476351690704222 det_TKEO_mean_1_coef Ed_3_coef
# 0.9925871118483761 det_TKEO_mean_1_coef det_entropy_shannon_1_coef
# 0.938281749284582 det_TKEO_mean_1_coef det_entropy_shannon_2_coef
# 0.8164482783888894 det_TKEO_mean_1_coef det_entropy_shannon_3_coef
# 0.9035306877002298 det_TKEO_mean_2_coef Ed_2_coef
# 0.918907960111802 det_TKEO_mean_2_coef Ed_3_coef
# 0.8974104698720492 det_TKEO_mean_2_coef det_entropy_shannon_1_coef
# 0.9936838620519937 det_TKEO_mean_2_coef det_entropy_shannon_2_coef
# 0.9141051570896067 det_TKEO_mean_2_coef det_entropy_shannon_3_coef
# 0.9312836811512322 det_TKEO_mean_2_coef det_TKEO_mean_1_coef
# 0.8026292297666167 det_TKEO_mean_3_coef Ed_2_coef
# 0.9565716406481565 det_TKEO_mean_3_coef Ed_3_coef
# 0.9326852240326342 det_TKEO_mean_3_coef det_entropy_shannon_2_coef
# 0.9953604427096222 det_TKEO_mean_3_coef det_entropy_shannon_3_coef
# 0.8073303028409861 det_TKEO_mean_3_coef det_TKEO_mean_1_coef
# 0.9141978113118077 det_TKEO_mean_3_coef det_TKEO_mean_2_coef
# 0.9878695548319639 det_TKEO_mean_4_coef det_entropy_shannon_4_coef
# 0.8318927112951113 det_TKEO_mean_5_coef Ed_5_coef
# 0.9692491053831016 det_TKEO_mean_5_coef det_entropy_shannon_5_coef
# 0.9496205363816719 det_TKEO_mean_6_coef det_entropy_shannon_6_coef
# 0.9891970934603692 det_TKEO_mean_7_coef det_entropy_shannon_7_coef
# 0.8225979416851614 det_TKEO_mean_8_coef Ed_8_coef
# 0.9975125634427557 det_TKEO_mean_8_coef det_entropy_shannon_8_coef
# 0.8224444933364572 det_TKEO_mean_8_coef det_entropy_shannon_10_coef
# 0.9880510015736219 det_TKEO_mean_9_coef det_entropy_shannon_9_coef
# 0.8065692125479631 det_TKEO_mean_9_coef det_entropy_shannon_10_coef
# 0.807763618747747 det_TKEO_mean_10_coef Ed_8_coef
# 0.8335422710765641 det_TKEO_mean_10_coef Ed_10_coef
# 0.8432559487474135 det_TKEO_mean_10_coef det_entropy_shannon_8_coef
# 0.9992235210783567 det_TKEO_mean_10_coef det_entropy_shannon_10_coef
# 0.8193288855562427 det_TKEO_mean_10_coef det_TKEO_mean_8_coef
# 0.8213605459954304 det_TKEO_std_1_coef Ed_1_coef
# 0.937094459072638 det_TKEO_std_1_coef det_entropy_shannon_1_coef
# 0.8046724210008891 det_TKEO_std_1_coef det_entropy_shannon_2_coef
# 0.9370380774360858 det_TKEO_std_1_coef det_TKEO_mean_1_coef
# 0.8173528598889317 det_TKEO_std_1_coef det_TKEO_mean_2_coef
# 0.8559295228505367 det_TKEO_std_2_coef Ed_2_coef
# 0.838539442031127 det_TKEO_std_2_coef Ed_3_coef
# 0.8643719364381447 det_TKEO_std_2_coef det_entropy_shannon_1_coef
# 0.9532200743997898 det_TKEO_std_2_coef det_entropy_shannon_2_coef
# 0.8438085496298797 det_TKEO_std_2_coef det_entropy_shannon_3_coef
# 0.8954226032899296 det_TKEO_std_2_coef det_TKEO_mean_1_coef
# 0.9756505904155771 det_TKEO_std_2_coef det_TKEO_mean_2_coef
# 0.8404193935774449 det_TKEO_std_2_coef det_TKEO_mean_3_coef
# 0.8259742185086543 det_TKEO_std_2_coef det_TKEO_std_1_coef
# 0.8396545888327586 det_TKEO_std_3_coef Ed_3_coef
# 0.8671672311354641 det_TKEO_std_3_coef det_entropy_shannon_2_coef
# 0.9376382005974151 det_TKEO_std_3_coef det_entropy_shannon_3_coef
# 0.8696505682003016 det_TKEO_std_3_coef det_TKEO_mean_2_coef
# 0.9193915370597225 det_TKEO_std_3_coef det_TKEO_mean_3_coef
# 0.833360414294506 det_TKEO_std_3_coef det_TKEO_std_2_coef
# 0.9575334611992075 det_TKEO_std_4_coef det_entropy_shannon_4_coef
# 0.9557227605947494 det_TKEO_std_4_coef det_TKEO_mean_4_coef
# 0.8562197705747422 det_TKEO_std_5_coef Ed_5_coef
# 0.987090753534965 det_TKEO_std_5_coef det_entropy_shannon_5_coef
# 0.9581780934868764 det_TKEO_std_5_coef det_TKEO_mean_5_coef
# 0.9896665003679734 det_TKEO_std_6_coef det_entropy_shannon_6_coef
# 0.9396270055267213 det_TKEO_std_6_coef det_TKEO_mean_6_coef
# 0.9947971191711923 det_TKEO_std_7_coef det_entropy_shannon_7_coef
# 0.9947263903997567 det_TKEO_std_7_coef det_TKEO_mean_7_coef
# 0.8375838168280062 det_TKEO_std_8_coef Ed_8_coef
# 0.998711931947521 det_TKEO_std_8_coef det_entropy_shannon_8_coef
# 0.8501543512192303 det_TKEO_std_8_coef det_entropy_shannon_10_coef
# 0.9976591186942799 det_TKEO_std_8_coef det_TKEO_mean_8_coef
# 0.8470955108430042 det_TKEO_std_8_coef det_TKEO_mean_10_coef
# 0.9785069536159291 det_TKEO_std_9_coef det_entropy_shannon_9_coef
# 0.9851255042333779 det_TKEO_std_9_coef det_TKEO_mean_9_coef
# 0.8106731965351102 det_TKEO_std_10_coef Ed_8_coef
# 0.8200533799917942 det_TKEO_std_10_coef Ed_10_coef
# 0.8540358565187819 det_TKEO_std_10_coef det_entropy_shannon_8_coef
# 0.9982771235533205 det_TKEO_std_10_coef det_entropy_shannon_10_coef
# 0.8305473294117033 det_TKEO_std_10_coef det_TKEO_mean_8_coef
# 0.9990122023620508 det_TKEO_std_10_coef det_TKEO_mean_10_coef
# 0.8577245483744332 det_TKEO_std_10_coef det_TKEO_std_8_coef
# 0.8934021356602077 app_entropy_shannon_1_coef numPulses
# 0.8928035979292278 app_entropy_shannon_1_coef numPeriodsPulses
# 0.893598591583866 app_entropy_shannon_2_coef numPulses
# 0.8931142316913624 app_entropy_shannon_2_coef numPeriodsPulses
# 0.9997440612100864 app_entropy_shannon_2_coef app_entropy_shannon_1_coef
# 0.8931855927792812 app_entropy_shannon_3_coef numPulses
# 0.8928168756868478 app_entropy_shannon_3_coef numPeriodsPulses
# 0.9987738004126576 app_entropy_shannon_3_coef app_entropy_shannon_1_coef
# 0.9996298415479353 app_entropy_shannon_3_coef app_entropy_shannon_2_coef
# 0.8923666815714256 app_entropy_shannon_4_coef numPulses
# 0.8920960578983004 app_entropy_shannon_4_coef numPeriodsPulses
# 0.9998190789199287 app_entropy_shannon_9_coef app_entropy_shannon_6_coef
# 0.99989227464264 app_entropy_shannon_9_coef app_entropy_shannon_7_coef
# 0.9999994159959196 app_entropy_shannon_9_coef app_entropy_shannon_8_coef
# 0.8866613064317836 app_entropy_shannon_10_coef numPulses
# 0.8865562140401391 app_entropy_shannon_10_coef numPeriodsPulses
# 0.9896306857039059 app_entropy_shannon_10_coef app_entropy_shannon_1_coef
# 0.9924367463357102 app_entropy_shannon_10_coef app_entropy_shannon_2_coef
# 0.9952652693082648 app_entropy_shannon_10_coef app_entropy_shannon_3_coef
# 0.9977758659858328 app_entropy_shannon_10_coef app_entropy_shannon_4_coef
# 0.9992170319352419 app_entropy_shannon_10_coef app_entropy_shannon_5_coef
# 0.999804480089105 app_entropy_shannon_10_coef app_entropy_shannon_6_coef
# 0.999881043963701 app_entropy_shannon_10_coef app_entropy_shannon_7_coef
# 0.9999961567144257 app_entropy_shannon_10_coef app_entropy_shannon_8_coef
# 0.999998194076305 app_entropy_shannon_10_coef app_entropy_shannon_9_coef
# 0.999028496960364 app_entropy_log_2_coef app_entropy_log_1_coef
# 0.819426168546885 app_entropy_log_3_coef numPulses
# 0.8197024415245601 app_entropy_log_3_coef numPeriodsPulses
# 0.9936844958640848 app_entropy_log_3_coef app_entropy_log_1_coef
# 0.9972825840716061 app_entropy_log_3_coef app_entropy_log_2_coef
# 0.8613361568419305 app_entropy_log_4_coef numPulses
# 0.8617399604523833 app_entropy_log_4_coef numPeriodsPulses
# 0.8114436968567728 app_entropy_log_4_coef app_entropy_shannon_1_coef
# 0.8126250121965464 app_entropy_log_4_coef app_entropy_shannon_2_coef
# 0.813169697112022 app_entropy_log_4_coef app_entropy_shannon_3_coef
# 0.8118869725029392 app_entropy_log_4_coef app_entropy_shannon_4_coef
# 0.8096288331494353 app_entropy_log_4_coef app_entropy_shannon_5_coef
# 0.8073695901473005 app_entropy_log_4_coef app_entropy_shannon_6_coef
# 0.8075281007978731 app_entropy_log_4_coef app_entropy_shannon_7_coef
# 0.8037245843572567 app_entropy_log_4_coef app_entropy_shannon_8_coef
# 0.804104476392124 app_entropy_log_4_coef app_entropy_shannon_9_coef
# 0.8044913498603828 app_entropy_log_4_coef app_entropy_shannon_10_coef
# 0.967107680707709 app_entropy_log_4_coef app_entropy_log_1_coef
# 0.9764988555945487 app_entropy_log_4_coef app_entropy_log_2_coef
# 0.9889913476240336 app_entropy_log_4_coef app_entropy_log_3_coef
# 0.8873272574879895 app_entropy_log_5_coef numPulses
# 0.8878713436837148 app_entropy_log_5_coef numPeriodsPulses
# 0.8007833743168126 app_entropy_log_5_coef meanPeriodPulses
# 0.8516481044977885 app_entropy_log_5_coef app_entropy_shannon_1_coef
# 0.8547082152153251 app_entropy_log_5_coef app_entropy_shannon_2_coef
# 0.8576209372154782 app_entropy_log_5_coef app_entropy_shannon_3_coef
# 0.8595090162169331 app_entropy_log_5_coef app_entropy_shannon_4_coef
# 0.8600988160100499 app_entropy_log_5_coef app_entropy_shannon_5_coef
# 0.8600059633307109 app_entropy_log_5_coef app_entropy_shannon_6_coef
# 0.8606651194158685 app_entropy_log_5_coef app_entropy_shannon_7_coef
# 0.8585738128787825 app_entropy_log_5_coef app_entropy_shannon_8_coef
# 0.8589841910678938 app_entropy_log_5_coef app_entropy_shannon_9_coef
# 0.8594080907689107 app_entropy_log_5_coef app_entropy_shannon_10_coef
# 0.9139365237238977 app_entropy_log_5_coef app_entropy_log_1_coef
# 0.9292991621205203 app_entropy_log_5_coef app_entropy_log_2_coef
# 0.9527662037327543 app_entropy_log_5_coef app_entropy_log_3_coef
# 0.9866956988772438 app_entropy_log_5_coef app_entropy_log_4_coef
# 0.890448254230273 app_entropy_log_6_coef numPulses
# 0.8911036731538805 app_entropy_log_6_coef numPeriodsPulses
# 0.8276560577003296 app_entropy_log_6_coef meanPeriodPulses
# 0.8678771628282711 app_entropy_log_6_coef app_entropy_shannon_1_coef
# 0.872560303129983 app_entropy_log_6_coef app_entropy_shannon_2_coef
# 0.8775617177187662 app_entropy_log_6_coef app_entropy_shannon_3_coef
# 0.8823344144833272 app_entropy_log_6_coef app_entropy_shannon_4_coef
# 0.8854609037603026 app_entropy_log_6_coef app_entropy_shannon_5_coef
# 0.8873998159455663 app_entropy_log_6_coef app_entropy_shannon_6_coef
# 0.888455698417487 app_entropy_log_6_coef app_entropy_shannon_7_coef
# 0.8879258507684561 app_entropy_log_6_coef app_entropy_shannon_8_coef
# 0.8883556134381386 app_entropy_log_6_coef app_entropy_shannon_9_coef
# 0.888803022362484 app_entropy_log_6_coef app_entropy_shannon_10_coef
# 0.8459251437823815 app_entropy_log_6_coef app_entropy_log_1_coef
# 0.8662206022462461 app_entropy_log_6_coef app_entropy_log_2_coef
# 0.8988488044004957 app_entropy_log_6_coef app_entropy_log_3_coef
# 0.9529671255053282 app_entropy_log_6_coef app_entropy_log_4_coef
# 0.9892257812189595 app_entropy_log_6_coef app_entropy_log_5_coef
# 0.8885385357235405 app_entropy_log_7_coef numPulses
# 0.889221674178587 app_entropy_log_7_coef numPeriodsPulses
# 0.8286058770810785 app_entropy_log_7_coef meanPeriodPulses
# 0.8676984269621444 app_entropy_log_7_coef app_entropy_shannon_1_coef
# 0.872566132640901 app_entropy_log_7_coef app_entropy_shannon_2_coef
# 0.8778519232057783 app_entropy_log_7_coef app_entropy_shannon_3_coef
# 0.8828782640818114 app_entropy_log_7_coef app_entropy_shannon_4_coef
# 0.8863046301542692 app_entropy_log_7_coef app_entropy_shannon_5_coef
# 0.8884449384917453 app_entropy_log_7_coef app_entropy_shannon_6_coef
# 0.8897116173068523 app_entropy_log_7_coef app_entropy_shannon_7_coef
# 0.8891903271607544 app_entropy_log_7_coef app_entropy_shannon_8_coef
# 0.8896199143654294 app_entropy_log_7_coef app_entropy_shannon_9_coef
# 0.8900678075398981 app_entropy_log_7_coef app_entropy_shannon_10_coef
# 0.8347452644640764 app_entropy_log_7_coef app_entropy_log_1_coef
# 0.8556460135051088 app_entropy_log_7_coef app_entropy_log_2_coef
# 0.8901481716909867 app_entropy_log_7_coef app_entropy_log_3_coef
# 0.9457106428515779 app_entropy_log_7_coef app_entropy_log_4_coef
# 0.9852156623017743 app_entropy_log_7_coef app_entropy_log_5_coef
# 0.9982609374924261 app_entropy_log_7_coef app_entropy_log_6_coef
# 0.8675582708590135 app_entropy_log_8_coef numPulses
# 0.8683417659974225 app_entropy_log_8_coef numPeriodsPulses
# 0.8417115822250171 app_entropy_log_8_coef meanPeriodPulses
# 0.8647026245031959 app_entropy_log_8_coef app_entropy_shannon_1_coef
# 0.871341721406719 app_entropy_log_8_coef app_entropy_shannon_2_coef
# 0.8787803617682229 app_entropy_log_8_coef app_entropy_shannon_3_coef
# 0.8870563120985855 app_entropy_log_8_coef app_entropy_shannon_4_coef
# 0.8933980443900537 app_entropy_log_8_coef app_entropy_shannon_5_coef
# 0.8977633881279521 app_entropy_log_8_coef app_entropy_shannon_6_coef
# 0.8993280229299363 app_entropy_log_8_coef app_entropy_shannon_7_coef
# 0.9011979151349224 app_entropy_log_8_coef app_entropy_shannon_8_coef
# 0.9016360891338773 app_entropy_log_8_coef app_entropy_shannon_9_coef
# 0.9020940800790147 app_entropy_log_8_coef app_entropy_shannon_10_coef
# 0.8715613528679229 app_entropy_log_8_coef app_entropy_log_4_coef
# 0.93896910604455 app_entropy_log_8_coef app_entropy_log_5_coef
# 0.9776643283665017 app_entropy_log_8_coef app_entropy_log_6_coef
# 0.9798933902493748 app_entropy_log_8_coef app_entropy_log_7_coef
# 0.8675732589736743 app_entropy_log_9_coef numPulses
# 0.868354930754192 app_entropy_log_9_coef numPeriodsPulses
# 0.841763856330464 app_entropy_log_9_coef meanPeriodPulses
# 0.8647640978410802 app_entropy_log_9_coef app_entropy_shannon_1_coef
# 0.8714008198324347 app_entropy_log_9_coef app_entropy_shannon_2_coef
# 0.8788377039379015 app_entropy_log_9_coef app_entropy_shannon_3_coef
# 0.8871110410545485 app_entropy_log_9_coef app_entropy_shannon_4_coef
# 0.8934513752891332 app_entropy_log_9_coef app_entropy_shannon_5_coef
# 0.8978158664675919 app_entropy_log_9_coef app_entropy_shannon_6_coef
# 0.899380039282163 app_entropy_log_9_coef app_entropy_shannon_7_coef
# 0.9012492197530709 app_entropy_log_9_coef app_entropy_shannon_8_coef
# 0.901687233314758 app_entropy_log_9_coef app_entropy_shannon_9_coef
# 0.9021448978454186 app_entropy_log_9_coef app_entropy_shannon_10_coef
# 0.8715361744652826 app_entropy_log_9_coef app_entropy_log_4_coef
# 0.9389502914497023 app_entropy_log_9_coef app_entropy_log_5_coef
# 0.977650940259661 app_entropy_log_9_coef app_entropy_log_6_coef
# 0.9798812904526064 app_entropy_log_9_coef app_entropy_log_7_coef
# 0.9999997737514938 app_entropy_log_9_coef app_entropy_log_8_coef
# 0.8675269747144333 app_entropy_log_10_coef numPulses
# 0.8683061694084176 app_entropy_log_10_coef numPeriodsPulses
# 0.841827368476705 app_entropy_log_10_coef meanPeriodPulses
# 0.8648430467722331 app_entropy_log_10_coef app_entropy_shannon_1_coef
# 0.8714783860352727 app_entropy_log_10_coef app_entropy_shannon_2_coef
# 0.8789136330436096 app_entropy_log_10_coef app_entropy_shannon_3_coef
# 0.8871881870741473 app_entropy_log_10_coef app_entropy_shannon_4_coef
# 0.8935329058465431 app_entropy_log_10_coef app_entropy_shannon_5_coef
# 0.8979011067239684 app_entropy_log_10_coef app_entropy_shannon_6_coef
# 0.8994636145618057 app_entropy_log_10_coef app_entropy_shannon_7_coef
# 0.9013319752209654 app_entropy_log_10_coef app_entropy_shannon_8_coef
# 0.901769332952353 app_entropy_log_10_coef app_entropy_shannon_9_coef
# 0.9022222517977443 app_entropy_log_10_coef app_entropy_shannon_10_coef
# 0.8715058611891057 app_entropy_log_10_coef app_entropy_log_4_coef
# 0.9389177216725254 app_entropy_log_10_coef app_entropy_log_5_coef
# 0.9776205239954932 app_entropy_log_10_coef app_entropy_log_6_coef
# 0.9798448881985059 app_entropy_log_10_coef app_entropy_log_7_coef
# 0.9999917448855185 app_entropy_log_10_coef app_entropy_log_8_coef
# 0.9999923453188718 app_entropy_log_10_coef app_entropy_log_9_coef
# 0.8546399415012078 app_det_TKEO_mean_2_coef app_entropy_shannon_1_coef
# 0.8520627516371281 app_det_TKEO_mean_2_coef app_entropy_shannon_2_coef
# 0.8499095315311226 app_det_TKEO_mean_2_coef app_entropy_shannon_3_coef
# 0.8479147824766062 app_det_TKEO_mean_2_coef app_entropy_shannon_4_coef
# 0.8472171581728021 app_det_TKEO_mean_2_coef app_entropy_shannon_5_coef
# 0.8470961633030558 app_det_TKEO_mean_2_coef app_entropy_shannon_6_coef
# 0.8469626376284006 app_det_TKEO_mean_2_coef app_entropy_shannon_7_coef
# 0.8461897581202551 app_det_TKEO_mean_2_coef app_entropy_shannon_8_coef
# 0.8460421025259813 app_det_TKEO_mean_2_coef app_entropy_shannon_9_coef
# 0.845664844884214 app_det_TKEO_mean_2_coef app_entropy_shannon_10_coef
# 0.9162363401751483 app_det_TKEO_mean_2_coef app_det_TKEO_mean_1_coef
# 0.8116681696855841 app_det_TKEO_mean_3_coef numPulses
# 0.8099923004912587 app_det_TKEO_mean_3_coef numPeriodsPulses
# 0.9296860156947053 app_det_TKEO_mean_3_coef app_entropy_shannon_1_coef
# 0.9309903930358452 app_det_TKEO_mean_3_coef app_entropy_shannon_2_coef
# 0.9330385830664029 app_det_TKEO_mean_3_coef app_entropy_shannon_3_coef
# 0.9345266083212428 app_det_TKEO_mean_3_coef app_entropy_shannon_4_coef
# 0.9363020737613267 app_det_TKEO_mean_3_coef app_entropy_shannon_5_coef
# 0.9376052541047172 app_det_TKEO_mean_3_coef app_entropy_shannon_6_coef
# 0.9379189764482545 app_det_TKEO_mean_3_coef app_entropy_shannon_7_coef
# 0.9375662180703939 app_det_TKEO_mean_3_coef app_entropy_shannon_8_coef
# 0.9375025441408763 app_det_TKEO_mean_3_coef app_entropy_shannon_9_coef
# 0.9372298993709361 app_det_TKEO_mean_3_coef app_entropy_shannon_10_coef
# 0.8139702937007617 app_det_TKEO_mean_3_coef app_entropy_log_6_coef
# 0.8164769161217208 app_det_TKEO_mean_3_coef app_entropy_log_7_coef
# 0.8370497027771473 app_det_TKEO_mean_3_coef app_entropy_log_8_coef
# 0.8372053359287811 app_det_TKEO_mean_3_coef app_entropy_log_9_coef
# 0.8374580211702797 app_det_TKEO_mean_3_coef app_entropy_log_10_coef
# 0.9633817875975585 app_det_TKEO_mean_3_coef app_det_TKEO_mean_2_coef
# 0.8608952423476453 app_det_TKEO_mean_4_coef numPulses
# 0.8601605421674072 app_det_TKEO_mean_4_coef numPeriodsPulses
# 0.9666545853626916 app_det_TKEO_mean_4_coef app_entropy_shannon_1_coef
# 0.9695339533939241 app_det_TKEO_mean_4_coef app_entropy_shannon_2_coef
# 0.9729889261764102 app_det_TKEO_mean_4_coef app_entropy_shannon_3_coef
# 0.9760301747181915 app_det_TKEO_mean_4_coef app_entropy_shannon_4_coef
# 0.9784508583150322 app_det_TKEO_mean_4_coef app_entropy_shannon_5_coef
# 0.9799707990533448 app_det_TKEO_mean_4_coef app_entropy_shannon_6_coef
# 0.9803701480105984 app_det_TKEO_mean_4_coef app_entropy_shannon_7_coef
# 0.980393215275365 app_det_TKEO_mean_4_coef app_entropy_shannon_8_coef
# 0.9803911876335216 app_det_TKEO_mean_4_coef app_entropy_shannon_9_coef
# 0.9802858810422383 app_det_TKEO_mean_4_coef app_entropy_shannon_10_coef
# 0.8356442622422524 app_det_TKEO_mean_4_coef app_entropy_log_5_coef
# 0.8702191875460101 app_det_TKEO_mean_4_coef app_entropy_log_6_coef
# 0.872455057959537 app_det_TKEO_mean_4_coef app_entropy_log_7_coef
# 0.8903167778826864 app_det_TKEO_mean_4_coef app_entropy_log_8_coef
# 0.8904193983683133 app_det_TKEO_mean_4_coef app_entropy_log_9_coef
# 0.8905432626465026 app_det_TKEO_mean_4_coef app_entropy_log_10_coef
# 0.9077629008980396 app_det_TKEO_mean_4_coef app_det_TKEO_mean_2_coef
# 0.9810433577218576 app_det_TKEO_mean_4_coef app_det_TKEO_mean_3_coef
# 0.8710653168223844 app_det_TKEO_mean_5_coef numPulses
# 0.8707385215172587 app_det_TKEO_mean_5_coef numPeriodsPulses
# 0.9741313404762905 app_det_TKEO_mean_5_coef app_entropy_shannon_1_coef
# 0.9774502353820081 app_det_TKEO_mean_5_coef app_entropy_shannon_2_coef
# 0.9812305641128489 app_det_TKEO_mean_5_coef app_entropy_shannon_3_coef
# 0.9843034009244164 app_det_TKEO_mean_5_coef app_entropy_shannon_4_coef
# 0.9866117405589401 app_det_TKEO_mean_5_coef app_entropy_shannon_5_coef
# 0.9879238712321817 app_det_TKEO_mean_5_coef app_entropy_shannon_6_coef
# 0.9882677045387163 app_det_TKEO_mean_5_coef app_entropy_shannon_7_coef
# 0.9881294071330524 app_det_TKEO_mean_5_coef app_entropy_shannon_8_coef
# 0.988134375107407 app_det_TKEO_mean_5_coef app_entropy_shannon_9_coef
# 0.9880442936023601 app_det_TKEO_mean_5_coef app_entropy_shannon_10_coef
# 0.8490859815615555 app_det_TKEO_mean_5_coef app_entropy_log_5_coef
# 0.8814160206259442 app_det_TKEO_mean_5_coef app_entropy_log_6_coef
# 0.8832759617179806 app_det_TKEO_mean_5_coef app_entropy_log_7_coef
# 0.8981102483111745 app_det_TKEO_mean_5_coef app_entropy_log_8_coef
# 0.8981965435445095 app_det_TKEO_mean_5_coef app_entropy_log_9_coef
# 0.8982958602563677 app_det_TKEO_mean_5_coef app_entropy_log_10_coef
# 0.8811489822523694 app_det_TKEO_mean_5_coef app_det_TKEO_mean_2_coef
# 0.9684564401947843 app_det_TKEO_mean_5_coef app_det_TKEO_mean_3_coef
# 0.9972209887714399 app_det_TKEO_mean_5_coef app_det_TKEO_mean_4_coef
# 0.8787201356192086 app_det_TKEO_mean_6_coef numPulses
# 0.8784792787838607 app_det_TKEO_mean_6_coef numPeriodsPulses
# 0.9796015867760147 app_det_TKEO_mean_6_coef app_entropy_shannon_1_coef
# 0.9827231696882887 app_det_TKEO_mean_6_coef app_entropy_shannon_2_coef
# 0.9861836548732662 app_det_TKEO_mean_6_coef app_entropy_shannon_3_coef
# 0.9888537947365938 app_det_TKEO_mean_6_coef app_entropy_shannon_4_coef
# 0.9907261911775579 app_det_TKEO_mean_6_coef app_entropy_shannon_5_coef
# 0.9916631660617665 app_det_TKEO_mean_6_coef app_entropy_shannon_6_coef
# 0.9919115605690156 app_det_TKEO_mean_6_coef app_entropy_shannon_7_coef
# 0.9916211745631122 app_det_TKEO_mean_6_coef app_entropy_shannon_8_coef
# 0.9916276976185358 app_det_TKEO_mean_6_coef app_entropy_shannon_9_coef
# 0.9915425262023733 app_det_TKEO_mean_6_coef app_entropy_shannon_10_coef
# 0.800252254466207 app_det_TKEO_mean_6_coef app_entropy_log_4_coef
# 0.8559031112674277 app_det_TKEO_mean_6_coef app_entropy_log_5_coef
# 0.8863149963921297 app_det_TKEO_mean_6_coef app_entropy_log_6_coef
# 0.8878737907723989 app_det_TKEO_mean_6_coef app_entropy_log_7_coef
# 0.9006978072076022 app_det_TKEO_mean_6_coef app_entropy_log_8_coef
# 0.9007775602834265 app_det_TKEO_mean_6_coef app_entropy_log_9_coef
# 0.9008834812033817 app_det_TKEO_mean_6_coef app_entropy_log_10_coef
# 0.8719685540178852 app_det_TKEO_mean_6_coef app_det_TKEO_mean_2_coef
# 0.9624600219170933 app_det_TKEO_mean_6_coef app_det_TKEO_mean_3_coef
# 0.9939638273823026 app_det_TKEO_mean_6_coef app_det_TKEO_mean_4_coef
# 0.9990073384884841 app_det_TKEO_mean_6_coef app_det_TKEO_mean_5_coef
# 0.8834310163008888 app_det_TKEO_mean_7_coef numPulses
# 0.8832232825375047 app_det_TKEO_mean_7_coef numPeriodsPulses
# 0.9828100583077332 app_det_TKEO_mean_7_coef app_entropy_shannon_1_coef
# 0.9857755598643502 app_det_TKEO_mean_7_coef app_entropy_shannon_2_coef
# 0.9889845023361529 app_det_TKEO_mean_7_coef app_entropy_shannon_3_coef
# 0.9914360052273875 app_det_TKEO_mean_7_coef app_entropy_shannon_4_coef
# 0.9930223348619083 app_det_TKEO_mean_7_coef app_entropy_shannon_5_coef
# 0.9937242077663617 app_det_TKEO_mean_7_coef app_entropy_shannon_6_coef
# 0.9938932662407763 app_det_TKEO_mean_7_coef app_entropy_shannon_7_coef
# 0.9936149831902813 app_det_TKEO_mean_7_coef app_entropy_shannon_8_coef
# 0.9936250786089894 app_det_TKEO_mean_7_coef app_entropy_shannon_9_coef
# 0.9935575978726978 app_det_TKEO_mean_7_coef app_entropy_shannon_10_coef
# 0.8033071791369693 app_det_TKEO_mean_7_coef app_entropy_log_4_coef
# 0.8585138855820499 app_det_TKEO_mean_7_coef app_entropy_log_5_coef
# 0.888461936994849 app_det_TKEO_mean_7_coef app_entropy_log_6_coef
# 0.8896874930279228 app_det_TKEO_mean_7_coef app_entropy_log_7_coef
# 0.9024505538403248 app_det_TKEO_mean_7_coef app_entropy_log_8_coef
# 0.902525478770682 app_det_TKEO_mean_7_coef app_entropy_log_9_coef
# 0.9026219747047071 app_det_TKEO_mean_7_coef app_entropy_log_10_coef
# 0.865216015364444 app_det_TKEO_mean_7_coef app_det_TKEO_mean_2_coef
# 0.9573621851756612 app_det_TKEO_mean_7_coef app_det_TKEO_mean_3_coef
# 0.9912768904081518 app_det_TKEO_mean_7_coef app_det_TKEO_mean_4_coef
# 0.9974180200909826 app_det_TKEO_mean_7_coef app_det_TKEO_mean_5_coef
# 0.9995333765951024 app_det_TKEO_mean_7_coef app_det_TKEO_mean_6_coef
# 0.8901368676317795 app_det_TKEO_mean_8_coef numPulses
# 0.8899342836034474 app_det_TKEO_mean_8_coef numPeriodsPulses
# 0.9882248881316834 app_det_TKEO_mean_8_coef app_entropy_shannon_1_coef
# 0.9908097207367547 app_det_TKEO_mean_8_coef app_entropy_shannon_2_coef
# 0.9934787960367814 app_det_TKEO_mean_8_coef app_entropy_shannon_3_coef
# 0.9954421274832835 app_det_TKEO_mean_8_coef app_entropy_shannon_4_coef
# 0.9964535008179177 app_det_TKEO_mean_8_coef app_entropy_shannon_5_coef
# 0.9967131582398678 app_det_TKEO_mean_8_coef app_entropy_shannon_6_coef
# 0.9967648182461032 app_det_TKEO_mean_8_coef app_entropy_shannon_7_coef
# 0.9964138865012259 app_det_TKEO_mean_8_coef app_entropy_shannon_8_coef
# 0.9964253466919464 app_det_TKEO_mean_8_coef app_entropy_shannon_9_coef
# 0.9963956870012507 app_det_TKEO_mean_8_coef app_entropy_shannon_10_coef
# 0.8106650150315867 app_det_TKEO_mean_8_coef app_entropy_log_4_coef
# 0.8639691891859862 app_det_TKEO_mean_8_coef app_entropy_log_5_coef
# 0.8920975472309336 app_det_TKEO_mean_8_coef app_entropy_log_6_coef
# 0.8931859928476926 app_det_TKEO_mean_8_coef app_entropy_log_7_coef
# 0.9033773018145379 app_det_TKEO_mean_8_coef app_entropy_log_8_coef
# 0.9034457671826792 app_det_TKEO_mean_8_coef app_entropy_log_9_coef
# 0.9035107559069014 app_det_TKEO_mean_8_coef app_entropy_log_10_coef
# 0.8566635552183892 app_det_TKEO_mean_8_coef app_det_TKEO_mean_2_coef
# 0.9492884070462891 app_det_TKEO_mean_8_coef app_det_TKEO_mean_3_coef
# 0.9872998819608824 app_det_TKEO_mean_8_coef app_det_TKEO_mean_4_coef
# 0.9944407672457745 app_det_TKEO_mean_8_coef app_det_TKEO_mean_5_coef
# 0.997563143357972 app_det_TKEO_mean_8_coef app_det_TKEO_mean_6_coef
# 0.999026680075484 app_det_TKEO_mean_8_coef app_det_TKEO_mean_7_coef
# 0.8902854667583051 app_det_TKEO_mean_9_coef numPulses
# 0.8900862287333327 app_det_TKEO_mean_9_coef numPeriodsPulses
# 0.9883444270837329 app_det_TKEO_mean_9_coef app_entropy_shannon_1_coef
# 0.9909386904187892 app_det_TKEO_mean_9_coef app_entropy_shannon_2_coef
# 0.9936123823090445 app_det_TKEO_mean_9_coef app_entropy_shannon_3_coef
# 0.9955989262365005 app_det_TKEO_mean_9_coef app_entropy_shannon_4_coef
# 0.9966212104616977 app_det_TKEO_mean_9_coef app_entropy_shannon_5_coef
# 0.9968902119254245 app_det_TKEO_mean_9_coef app_entropy_shannon_6_coef
# 0.9969414988103676 app_det_TKEO_mean_9_coef app_entropy_shannon_7_coef
# 0.9966136164647723 app_det_TKEO_mean_9_coef app_entropy_shannon_8_coef
# 0.9966258574985849 app_det_TKEO_mean_9_coef app_entropy_shannon_9_coef
# 0.9965993772573246 app_det_TKEO_mean_9_coef app_entropy_shannon_10_coef
# 0.8107829780715973 app_det_TKEO_mean_9_coef app_entropy_log_4_coef
# 0.8641640053135669 app_det_TKEO_mean_9_coef app_entropy_log_5_coef
# 0.8923534425875355 app_det_TKEO_mean_9_coef app_entropy_log_6_coef
# 0.8934221256425726 app_det_TKEO_mean_9_coef app_entropy_log_7_coef
# 0.9037310611117307 app_det_TKEO_mean_9_coef app_entropy_log_8_coef
# 0.9037991199477559 app_det_TKEO_mean_9_coef app_entropy_log_9_coef
# 0.9038639665058834 app_det_TKEO_mean_9_coef app_entropy_log_10_coef
# 0.8559745350880161 app_det_TKEO_mean_9_coef app_det_TKEO_mean_2_coef
# 0.9487005903379286 app_det_TKEO_mean_9_coef app_det_TKEO_mean_3_coef
# 0.9870535129986111 app_det_TKEO_mean_9_coef app_det_TKEO_mean_4_coef
# 0.9942305495189145 app_det_TKEO_mean_9_coef app_det_TKEO_mean_5_coef
# 0.9973831362132937 app_det_TKEO_mean_9_coef app_det_TKEO_mean_6_coef
# 0.9989078609560629 app_det_TKEO_mean_9_coef app_det_TKEO_mean_7_coef
# 0.9999927948973169 app_det_TKEO_mean_9_coef app_det_TKEO_mean_8_coef
# 0.8917438030923328 app_det_TKEO_mean_10_coef numPulses
# 0.891560622069266 app_det_TKEO_mean_10_coef numPeriodsPulses
# 0.9894428181508119 app_det_TKEO_mean_10_coef app_entropy_shannon_1_coef
# 0.9920190222325372 app_det_TKEO_mean_10_coef app_entropy_shannon_2_coef
# 0.9946354051673547 app_det_TKEO_mean_10_coef app_entropy_shannon_3_coef
# 0.9966404817468429 app_det_TKEO_mean_10_coef app_entropy_shannon_4_coef
# 0.9976413299893232 app_det_TKEO_mean_10_coef app_entropy_shannon_5_coef
# 0.9978973078323627 app_det_TKEO_mean_10_coef app_entropy_shannon_6_coef
# 0.9979340815390525 app_det_TKEO_mean_10_coef app_entropy_shannon_7_coef
# 0.9976853916517637 app_det_TKEO_mean_10_coef app_entropy_shannon_8_coef
# 0.9977005581782601 app_det_TKEO_mean_10_coef app_entropy_shannon_9_coef
# 0.9976954751824291 app_det_TKEO_mean_10_coef app_entropy_shannon_10_coef
# 0.811835303980016 app_det_TKEO_mean_10_coef app_entropy_log_4_coef
# 0.8653729490950247 app_det_TKEO_mean_10_coef app_entropy_log_5_coef
# 0.893643446630353 app_det_TKEO_mean_10_coef app_entropy_log_6_coef
# 0.8947017121625348 app_det_TKEO_mean_10_coef app_entropy_log_7_coef
# 0.9051161708243044 app_det_TKEO_mean_10_coef app_entropy_log_8_coef
# 0.9051804144388583 app_det_TKEO_mean_10_coef app_entropy_log_9_coef
# 0.9052237548833134 app_det_TKEO_mean_10_coef app_entropy_log_10_coef
# 0.8528994086271163 app_det_TKEO_mean_10_coef app_det_TKEO_mean_2_coef
# 0.945586531328175 app_det_TKEO_mean_10_coef app_det_TKEO_mean_3_coef
# 0.9855492895136475 app_det_TKEO_mean_10_coef app_det_TKEO_mean_4_coef
# 0.9929454759502826 app_det_TKEO_mean_10_coef app_det_TKEO_mean_5_coef
# 0.9962828720546255 app_det_TKEO_mean_10_coef app_det_TKEO_mean_6_coef
# 0.9980658462332636 app_det_TKEO_mean_10_coef app_det_TKEO_mean_7_coef
# 0.9997700993049515 app_det_TKEO_mean_10_coef app_det_TKEO_mean_8_coef
# 0.9998287359888552 app_det_TKEO_mean_10_coef app_det_TKEO_mean_9_coef
# 0.9453444515574261 app_TKEO_std_1_coef app_det_TKEO_mean_1_coef
# 0.9448084763093456 app_TKEO_std_1_coef app_det_TKEO_mean_2_coef
# 0.8714577758393129 app_TKEO_std_1_coef app_det_TKEO_mean_3_coef
# 0.8860299576289553 app_TKEO_std_2_coef app_entropy_shannon_1_coef
# 0.8837953914510194 app_TKEO_std_2_coef app_entropy_shannon_2_coef
# 0.8819582123203248 app_TKEO_std_2_coef app_entropy_shannon_3_coef
# 0.879916335290085 app_TKEO_std_2_coef app_entropy_shannon_4_coef
# 0.8790582963551724 app_TKEO_std_2_coef app_entropy_shannon_5_coef
# 0.8786166280980506 app_TKEO_std_2_coef app_entropy_shannon_6_coef
# 0.8784672633077454 app_TKEO_std_2_coef app_entropy_shannon_7_coef
# 0.8773204232352301 app_TKEO_std_2_coef app_entropy_shannon_8_coef
# 0.8771707701276221 app_TKEO_std_2_coef app_entropy_shannon_9_coef
# 0.8767571442957415 app_TKEO_std_2_coef app_entropy_shannon_10_coef
# 0.8904094424297493 app_TKEO_std_2_coef app_det_TKEO_mean_1_coef
# 0.9899461095594739 app_TKEO_std_2_coef app_det_TKEO_mean_2_coef
# 0.9718453126955713 app_TKEO_std_2_coef app_det_TKEO_mean_3_coef
# 0.9262878341232839 app_TKEO_std_2_coef app_det_TKEO_mean_4_coef
# 0.9063317952458521 app_TKEO_std_2_coef app_det_TKEO_mean_5_coef
# 0.9003944438395427 app_TKEO_std_2_coef app_det_TKEO_mean_6_coef
# 0.8950863067038861 app_TKEO_std_2_coef app_det_TKEO_mean_7_coef
# 0.8874524543681213 app_TKEO_std_2_coef app_det_TKEO_mean_8_coef
# 0.8867754115728704 app_TKEO_std_2_coef app_det_TKEO_mean_9_coef
# 0.8836306093933091 app_TKEO_std_2_coef app_det_TKEO_mean_10_coef
# 0.953522428398631 app_TKEO_std_2_coef app_TKEO_std_1_coef
# 0.8000874049079276 app_TKEO_std_3_coef numPulses
# 0.9416749369171697 app_TKEO_std_3_coef app_entropy_shannon_1_coef
# 0.9413110574894835 app_TKEO_std_3_coef app_entropy_shannon_2_coef
# 0.9411530954018971 app_TKEO_std_3_coef app_entropy_shannon_3_coef
# 0.9398892475304936 app_TKEO_std_3_coef app_entropy_shannon_4_coef
# 0.9393660430029925 app_TKEO_std_3_coef app_entropy_shannon_5_coef
# 0.9389236096961447 app_TKEO_std_3_coef app_entropy_shannon_6_coef
# 0.9386431268594131 app_TKEO_std_3_coef app_entropy_shannon_7_coef
# 0.9375356586744277 app_TKEO_std_3_coef app_entropy_shannon_8_coef
# 0.9373868930120908 app_TKEO_std_3_coef app_entropy_shannon_9_coef
# 0.9370161410222703 app_TKEO_std_3_coef app_entropy_shannon_10_coef
# 0.8087978497985601 app_TKEO_std_3_coef app_entropy_log_8_coef
# 0.8089515526166998 app_TKEO_std_3_coef app_entropy_log_9_coef
# 0.809294572634466 app_TKEO_std_3_coef app_entropy_log_10_coef
# 0.9624469067435881 app_TKEO_std_3_coef app_det_TKEO_mean_2_coef
# 0.9875576092452013 app_TKEO_std_3_coef app_det_TKEO_mean_3_coef
# 0.9667546975449032 app_TKEO_std_3_coef app_det_TKEO_mean_4_coef
# 0.9576361043490258 app_TKEO_std_3_coef app_det_TKEO_mean_5_coef
# 0.9545285189345449 app_TKEO_std_3_coef app_det_TKEO_mean_6_coef
# 0.9508271784454589 app_TKEO_std_3_coef app_det_TKEO_mean_7_coef
# 0.9453010859088222 app_TKEO_std_3_coef app_det_TKEO_mean_8_coef
# 0.944783302974489 app_TKEO_std_3_coef app_det_TKEO_mean_9_coef
# 0.9423011943738058 app_TKEO_std_3_coef app_det_TKEO_mean_10_coef
# 0.8941866852382205 app_TKEO_std_3_coef app_TKEO_std_1_coef
# 0.977553989685533 app_TKEO_std_3_coef app_TKEO_std_2_coef
# 0.8583861233475758 app_TKEO_std_4_coef numPulses
# 0.8572532707817145 app_TKEO_std_4_coef numPeriodsPulses
# 0.9638581834450696 app_TKEO_std_4_coef app_entropy_shannon_1_coef
# 0.9656356496353861 app_TKEO_std_4_coef app_entropy_shannon_2_coef
# 0.9679634317844031 app_TKEO_std_4_coef app_entropy_shannon_3_coef
# 0.9696722651797 app_TKEO_std_4_coef app_entropy_shannon_4_coef
# 0.9710287292927842 app_TKEO_std_4_coef app_entropy_shannon_5_coef
# 0.9717827489378428 app_TKEO_std_4_coef app_entropy_shannon_6_coef
# 0.9720098491822291 app_TKEO_std_4_coef app_entropy_shannon_7_coef
# 0.9714477248964641 app_TKEO_std_4_coef app_entropy_shannon_8_coef
# 0.9714301982643935 app_TKEO_std_4_coef app_entropy_shannon_9_coef
# 0.9712504533469556 app_TKEO_std_4_coef app_entropy_shannon_10_coef
# 0.8337531850638613 app_TKEO_std_4_coef app_entropy_log_5_coef
# 0.8634232776247789 app_TKEO_std_4_coef app_entropy_log_6_coef
# 0.8647716723605613 app_TKEO_std_4_coef app_entropy_log_7_coef
# 0.8774743177932796 app_TKEO_std_4_coef app_entropy_log_8_coef
# 0.8775996935823056 app_TKEO_std_4_coef app_entropy_log_9_coef
# 0.8778220035898536 app_TKEO_std_4_coef app_entropy_log_10_coef
# 0.923793370478352 app_TKEO_std_4_coef app_det_TKEO_mean_2_coef
# 0.9878085116687405 app_TKEO_std_4_coef app_det_TKEO_mean_3_coef
# 0.9939178683910203 app_TKEO_std_4_coef app_det_TKEO_mean_4_coef
# 0.9896500040733214 app_TKEO_std_4_coef app_det_TKEO_mean_5_coef
# 0.9881599098653463 app_TKEO_std_4_coef app_det_TKEO_mean_6_coef
# 0.9862094322340977 app_TKEO_std_4_coef app_det_TKEO_mean_7_coef
# 0.9819609710490665 app_TKEO_std_4_coef app_det_TKEO_mean_8_coef
# 0.9816015928324549 app_TKEO_std_4_coef app_det_TKEO_mean_9_coef
# 0.9792713897088969 app_TKEO_std_4_coef app_det_TKEO_mean_10_coef
# 0.8267939763947542 app_TKEO_std_4_coef app_TKEO_std_1_coef
# 0.9430521587479584 app_TKEO_std_4_coef app_TKEO_std_2_coef
# 0.9764120570340152 app_TKEO_std_4_coef app_TKEO_std_3_coef
# 0.8681042679086476 app_TKEO_std_5_coef numPulses
# 0.867501289951448 app_TKEO_std_5_coef numPeriodsPulses
# 0.9694372416644393 app_TKEO_std_5_coef app_entropy_shannon_1_coef
# 0.9722857013927795 app_TKEO_std_5_coef app_entropy_shannon_2_coef
# 0.9756729974617632 app_TKEO_std_5_coef app_entropy_shannon_3_coef
# 0.9783258789386465 app_TKEO_std_5_coef app_entropy_shannon_4_coef
# 0.9803901613988973 app_TKEO_std_5_coef app_entropy_shannon_5_coef
# 0.9814949437605859 app_TKEO_std_5_coef app_entropy_shannon_6_coef
# 0.9818282738239019 app_TKEO_std_5_coef app_entropy_shannon_7_coef
# 0.9813729066372546 app_TKEO_std_5_coef app_entropy_shannon_8_coef
# 0.9813700258140875 app_TKEO_std_5_coef app_entropy_shannon_9_coef
# 0.9812272658907959 app_TKEO_std_5_coef app_entropy_shannon_10_coef
# 0.846617942198404 app_TKEO_std_5_coef app_entropy_log_5_coef
# 0.8769566686672512 app_TKEO_std_5_coef app_entropy_log_6_coef
# 0.8788089313672682 app_TKEO_std_5_coef app_entropy_log_7_coef
# 0.8909445283119333 app_TKEO_std_5_coef app_entropy_log_8_coef
# 0.8910438779089966 app_TKEO_std_5_coef app_entropy_log_9_coef
# 0.8912105389880043 app_TKEO_std_5_coef app_entropy_log_10_coef
# 0.8952424210175423 app_TKEO_std_5_coef app_det_TKEO_mean_2_coef
# 0.9757518307573099 app_TKEO_std_5_coef app_det_TKEO_mean_3_coef
# 0.9974935748158316 app_TKEO_std_5_coef app_det_TKEO_mean_4_coef
# 0.9977477146855173 app_TKEO_std_5_coef app_det_TKEO_mean_5_coef
# 0.9962513033892877 app_TKEO_std_5_coef app_det_TKEO_mean_6_coef
# 0.9942083514631209 app_TKEO_std_5_coef app_det_TKEO_mean_7_coef
# 0.9902488744186727 app_TKEO_std_5_coef app_det_TKEO_mean_8_coef
# 0.9899433376496065 app_TKEO_std_5_coef app_det_TKEO_mean_9_coef
# 0.9879632857379154 app_TKEO_std_5_coef app_det_TKEO_mean_10_coef
# 0.9188369202448762 app_TKEO_std_5_coef app_TKEO_std_2_coef
# 0.9635928694019895 app_TKEO_std_5_coef app_TKEO_std_3_coef
# 0.9943634947887777 app_TKEO_std_5_coef app_TKEO_std_4_coef
# 0.8700361700602539 app_TKEO_std_6_coef numPulses
# 0.8696991903393506 app_TKEO_std_6_coef numPeriodsPulses
# 0.9717278895448723 app_TKEO_std_6_coef app_entropy_shannon_1_coef
# 0.9749879454330567 app_TKEO_std_6_coef app_entropy_shannon_2_coef
# 0.978733739963164 app_TKEO_std_6_coef app_entropy_shannon_3_coef
# 0.9815711067040708 app_TKEO_std_6_coef app_entropy_shannon_4_coef
# 0.9837353692557274 app_TKEO_std_6_coef app_entropy_shannon_5_coef
# 0.984905538563506 app_TKEO_std_6_coef app_entropy_shannon_6_coef
# 0.9852414116941066 app_TKEO_std_6_coef app_entropy_shannon_7_coef
# 0.9847951095351111 app_TKEO_std_6_coef app_entropy_shannon_8_coef
# 0.9847987515739046 app_TKEO_std_6_coef app_entropy_shannon_9_coef
# 0.9846734027495286 app_TKEO_std_6_coef app_entropy_shannon_10_coef
# 0.8529377130114053 app_TKEO_std_6_coef app_entropy_log_5_coef
# 0.882350684465174 app_TKEO_std_6_coef app_entropy_log_6_coef
# 0.8838920721042112 app_TKEO_std_6_coef app_entropy_log_7_coef
# 0.8952339909466728 app_TKEO_std_6_coef app_entropy_log_8_coef
# 0.8953246380635926 app_TKEO_std_6_coef app_entropy_log_9_coef
# 0.8954763249242665 app_TKEO_std_6_coef app_entropy_log_10_coef
# 0.88029462989146 app_TKEO_std_6_coef app_det_TKEO_mean_2_coef
# 0.9687805170962867 app_TKEO_std_6_coef app_det_TKEO_mean_3_coef
# 0.9959932790536418 app_TKEO_std_6_coef app_det_TKEO_mean_4_coef
# 0.9991620481762192 app_TKEO_std_6_coef app_det_TKEO_mean_5_coef
# 0.9984141222085444 app_TKEO_std_6_coef app_det_TKEO_mean_6_coef
# 0.9965995125371223 app_TKEO_std_6_coef app_det_TKEO_mean_7_coef
# 0.9929376177320224 app_TKEO_std_6_coef app_det_TKEO_mean_8_coef
# 0.9926657664995394 app_TKEO_std_6_coef app_det_TKEO_mean_9_coef
# 0.990880425877822 app_TKEO_std_6_coef app_det_TKEO_mean_10_coef
# 0.9067841512077266 app_TKEO_std_6_coef app_TKEO_std_2_coef
# 0.957816857390584 app_TKEO_std_6_coef app_TKEO_std_3_coef
# 0.9906227286332284 app_TKEO_std_6_coef app_TKEO_std_4_coef
# 0.9983509587866661 app_TKEO_std_6_coef app_TKEO_std_5_coef
# 0.8770534688819633 app_TKEO_std_7_coef numPulses
# 0.8766986249454065 app_TKEO_std_7_coef numPeriodsPulses
# 0.9830414824341338 app_TKEO_std_7_coef app_entropy_shannon_1_coef
# 0.985389247034917 app_TKEO_std_7_coef app_entropy_shannon_2_coef
# 0.9878709427087461 app_TKEO_std_7_coef app_entropy_shannon_3_coef
# 0.9894416001692459 app_TKEO_std_7_coef app_entropy_shannon_4_coef
# 0.9904798891613995 app_TKEO_std_7_coef app_entropy_shannon_5_coef
# 0.9907973927628432 app_TKEO_std_7_coef app_entropy_shannon_6_coef
# 0.9908162785212389 app_TKEO_std_7_coef app_entropy_shannon_7_coef
# 0.9901871450598552 app_TKEO_std_7_coef app_entropy_shannon_8_coef
# 0.9901569216437195 app_TKEO_std_7_coef app_entropy_shannon_9_coef
# 0.9899934595129528 app_TKEO_std_7_coef app_entropy_shannon_10_coef
# 0.847658062278536 app_TKEO_std_7_coef app_entropy_log_5_coef
# 0.8764312280038522 app_TKEO_std_7_coef app_entropy_log_6_coef
# 0.8779232458817184 app_TKEO_std_7_coef app_entropy_log_7_coef
# 0.8891981713323915 app_TKEO_std_7_coef app_entropy_log_8_coef
# 0.8892803531493612 app_TKEO_std_7_coef app_entropy_log_9_coef
# 0.8894850905987589 app_TKEO_std_7_coef app_entropy_log_10_coef
# 0.8836241010672913 app_TKEO_std_7_coef app_det_TKEO_mean_2_coef
# 0.9655340730849543 app_TKEO_std_7_coef app_det_TKEO_mean_3_coef
# 0.991739697528789 app_TKEO_std_7_coef app_det_TKEO_mean_4_coef
# 0.9963725030756415 app_TKEO_std_7_coef app_det_TKEO_mean_5_coef
# 0.9978487654176796 app_TKEO_std_7_coef app_det_TKEO_mean_6_coef
# 0.9973929963711774 app_TKEO_std_7_coef app_det_TKEO_mean_7_coef
# 0.9953346215150042 app_TKEO_std_7_coef app_det_TKEO_mean_8_coef
# 0.9951091019600106 app_TKEO_std_7_coef app_det_TKEO_mean_9_coef
# 0.9939049519181348 app_TKEO_std_7_coef app_det_TKEO_mean_10_coef
# 0.9129191044962713 app_TKEO_std_7_coef app_TKEO_std_2_coef
# 0.9639569086941203 app_TKEO_std_7_coef app_TKEO_std_3_coef
# 0.9879591100806167 app_TKEO_std_7_coef app_TKEO_std_4_coef
# 0.9946679827243124 app_TKEO_std_7_coef app_TKEO_std_5_coef
# 0.9961274989937867 app_TKEO_std_7_coef app_TKEO_std_6_coef
# 0.8855511139460615 app_TKEO_std_8_coef numPulses
# 0.8853145812216772 app_TKEO_std_8_coef numPeriodsPulses
# 0.9845748471484981 app_TKEO_std_8_coef app_entropy_shannon_1_coef
# 0.9450631236317399 tqwt_kurtosisValue_dec_35 tqwt_kurtosisValue_dec_34
# 0.8634890377075095 tqwt_kurtosisValue_dec_36 tqwt_kurtosisValue_dec_35
# 491

# %%
X_smote_scaled_correlated = X_smote_scaled
X_smote_scaled_correlated.drop(labels=corr_features, axis=1, inplace=True)


X_smote_scaled_correlated.shape
# Out:
# (1128, 263)

# %%
K = range (1, 10)
KM = [KMeans(n_clusters=k).fit(X_smote_scaled_correlated) for k in K]
centroids = [k.cluster_centers_ for k in KM]
D_k = [cdist(X_smote_scaled_correlated,cent,"euclidean") for cent in centroids]
cIdx = [np.argmin(D,axis=1) for D in D_k]
dist = [np.min(D,axis=1) for D in D_k]
avgWithinSS = [sum(d)/X.shape[0] for d in dist]

# %%
# total with -in sum of square
wcss = [sum(d**2) for d in dist ]
tss = sum(pdist(X_smote_scaled_correlated)**2)/X_smote_scaled_correlated. shape [0]
bss = tss - wcss
varExplained = bss / tss * 100

# %%
kIdx = 2
# plot
plt.figure(figsize =(10 , 4))
plt.subplot(1, 2, 1)
plt.plot(K, avgWithinSS , 'b*-')
plt.plot(K[kIdx], avgWithinSS [ kIdx ], marker ='o', markersize =12 ,
          markeredgewidth =2, markeredgecolor ='r', markerfacecolor ='None')
plt.grid (True)
plt.xlabel('Number of clusters')
plt.ylabel('Average within - cluster sum of squares')
plt.title('Elbow for k- means clustering')
plt.subplot(1, 2, 2)
plt.plot(K, varExplained, 'b*-')
plt.plot(K[kIdx],varExplained[kIdx], marker ='o', markersize =12 ,markeredgewidth =2, markeredgecolor ='r', markerfacecolor ='None')
plt.grid(True)
plt.xlabel("Number of clusters")
plt.ylabel("Percentage of variance explained")
plt.title("Elbow for k- means clustering")
plt.tight_layout()
plt.savefig("kmeans_elbow.png")
plt.show()

# %% [markdown]
# # Drop da Coluna Id

# %%
X_smote_scaled_correlated = X_smote_scaled_correlated.drop("id", axis=1)

# %% [markdown]
# # Split para dados de treino e teste e Logistic Regression

# %%
# Load the Iris dataset
iris = datasets.load_iris()

# Step 1: Cluster the data using K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
cluster_labels = kmeans.fit_predict(X_smote_scaled_correlated)

# Step 2: Split data into training and testing sets
X_train, X_test, y_train, y_test, cluster_train, cluster_test = train_test_split(X_smote_scaled_correlated, 
                                                                                 y_smote, 
                                                                                 cluster_labels, 
                                                                                 test_size=0.2, 
                                                                                 random_state=42)

# Step 3: Train and evaluate a classifier for each cluster
unique_clusters = np.unique(cluster_labels)

for cluster in unique_clusters:
    cluster_X_train = X_train[cluster_train == cluster]
    cluster_y_train = y_train[cluster_train == cluster]
    cluster_X_test = X_test[cluster_test == cluster]
    cluster_y_test = y_test[cluster_test == cluster]

    # Create a logistic regression classifier for this cluster
    classifier = LogisticRegression()
    classifier.fit(cluster_X_train, cluster_y_train)

    # Evaluate the classifier for this cluster
    accuracy = classifier.score(cluster_X_test, cluster_y_test)
    print(f"Cluster {cluster} - Accuracy: {accuracy:.2f}")

# Overall evaluation
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
overall_accuracy = classifier.score(X_test, y_test)
print(f"Overall Accuracy: {overall_accuracy:.2f}")
# Out:
# Cluster 0 - Accuracy: 0.91
# Cluster 1 - Accuracy: 0.87
# Cluster 2 - Accuracy: 0.88
# Overall Accuracy: 0.86

# %% [markdown]
# # Split para dados de treino e teste e Random Forest

# %%
import numpy as np
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# Step 1: Cluster the data using K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
cluster_labels = kmeans.fit_predict(X_smote_scaled_correlated)

# Step 2: Split the data into training and testing sets
X_train, X_test, y_train, y_test, cluster_train, cluster_test = train_test_split(X_smote_scaled_correlated, 
                                                                                 y_smote, 
                                                                                 cluster_labels, 
                                                                                 test_size=0.2, 
                                                                                 random_state=42)

# Step 3: Train a Random Forest classifier for each cluster
unique_clusters = np.unique(cluster_labels)
rf_models = {}

for cluster in unique_clusters:
    cluster_X_train = X_train[cluster_train == cluster]
    cluster_y_train = y_train[cluster_train == cluster]
    
    cluster_X_test = X_test[cluster_test == cluster]
    cluster_y_test = y_test[cluster_test == cluster]
    
    
    # Create a Random Forest classifier for this cluster
    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_classifier.fit(cluster_X_train, cluster_y_train)

    # Store the classifier in a dictionary
    rf_models[cluster] = rf_classifier
    
    # Evaluate the classifier for this cluster
    accuracy = classifier.score(cluster_X_test, cluster_y_test)
    print(f"Cluster {cluster} - Accuracy: {accuracy:.2f}")


# Overall evaluation
classifier = RandomForestClassifier(n_estimators=100, random_state=42)
classifier.fit(X_train, y_train)
overall_accuracy = classifier.score(X_test, y_test)
print(f"Overall Accuracy: {overall_accuracy:.2f}")
# Out:
# Cluster 0 - Accuracy: 0.88
# Cluster 1 - Accuracy: 0.84
# Cluster 2 - Accuracy: 0.86
# Overall Accuracy: 0.92

# %% [markdown]
# # Split para dados de treino e teste e SVM

# %%
import numpy as np
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# Step 1: Cluster the data using K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
cluster_labels = kmeans.fit_predict(X_smote_scaled_correlated)

# Step 2: Split the data into training and testing sets
X_train, X_test, y_train, y_test, cluster_train, cluster_test = train_test_split(X_smote_scaled_correlated, 
                                                                                 y_smote, 
                                                                                 cluster_labels, 
                                                                                 test_size=0.2, 
                                                                                 random_state=42)

# Step 3: Train a Random Forest classifier for each cluster
unique_clusters = np.unique(cluster_labels)
rf_models = {}

for cluster in unique_clusters:
    cluster_X_train = X_train[cluster_train == cluster]
    cluster_y_train = y_train[cluster_train == cluster]
    
    cluster_X_test = X_test[cluster_test == cluster]
    cluster_y_test = y_test[cluster_test == cluster]
    
    
    # Create a Random Forest classifier for this cluster
    svm_classifier = SVC(kernel='linear')
    svm_classifier.fit(cluster_X_train, cluster_y_train)
    
    # Evaluate the classifier for this cluster
    accuracy = classifier.score(cluster_X_test, cluster_y_test)
    print(f"Cluster {cluster} - Accuracy: {accuracy:.2f}")


# Overall evaluation
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X_train, y_train)
overall_accuracy = svm_classifier.score(X_test, y_test)
print(f"Overall Accuracy: {overall_accuracy:.2f}")
# Out:
# Cluster 0 - Accuracy: 0.93
# Cluster 1 - Accuracy: 0.93
# Cluster 2 - Accuracy: 0.91
# Overall Accuracy: 0.87
